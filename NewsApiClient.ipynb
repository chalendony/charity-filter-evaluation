# %%
# https://newsapi.org/docs/client-libraries/python

from newsapi.newsapi_client import NewsApiClient

apikey = 'a45b2d56b27c4c68bedd59c89f6005f1'

newsapi = NewsApiClient(api_key=apikey)

target_lst = ['museums', 'united ways', 'development and relief services',
              'advocacy and education', 'children and family services']

target_lst = ['children and family services']

lst = []
for topic in target_lst:
    print(topic)
    res = all_articles = newsapi.get_everything(q=topic,
                                          language='en',
                                          sort_by='relevancy',
                                                page=2)
    print(res)
# Out:
# children and family services
# {'status': 'ok', 'totalResults': 4752, 'articles': [{'source': {'id': None, 'name': 'Ctvnews.ca'}, 'author': 'CTV Vancouver', 'title': "'It's so hard to believe': Church elder identified as Salmon Arm shooting victim - CTV News", 'description': "'It's so hard to believe': Church elder identified as Salmon Arm shooting victim CTV News Arrest in fatal shooting - Salmon Arm News Castanet.net Elder killed in Salmon Arm church shooting: family Globalnews.ca 1 man dead, another person injured after shootin…", 'url': 'https://bc.ctvnews.ca/it-s-so-hard-to-believe-church-elder-identified-as-salmon-arm-shooting-victim-1.4379483', 'urlToImage': 'https://www.ctvnews.ca/polopoly_fs/1.4379740.1555296213!/httpImage/image.jpg_gen/derivatives/landscape_620/image.jpg', 'publishedAt': '2019-04-15T02:31:00Z', 'content': 'RCMP are investigating a deadly shooting at a Salmon Arm church that claimed the life of a church elder.\r\nSalmon Arm RCMP were called to the Church of Christ shortly after 10:30 a.m. Sunday.\r\nAccording to a church member, a bible session was happening at that… [+1504 chars]'}, {'source': {'id': None, 'name': 'Thisisinsider.com'}, 'author': 'Callie Ahlgrim', 'title': "Pink says she isn't sharing photos of her kids anymore after posting a controversial photo of her son without a diaper", 'description': 'During a Monday appearance on "The Ellen Show," Pink addressed a controversial photo she recently posted of her children. Pink removed the original photo, which showed her 2-year-old son Jameson without a diaper, and replaced it with a censored version after …', 'url': 'https://www.thisisinsider.com/pink-responds-to-controversial-photo-of-son-without-diaper-ellen-show-video-2019-4', 'urlToImage': 'https://amp.businessinsider.com/images/5cbf31ff2730ca301b4ba17e-2732-1366.jpg', 'publishedAt': '2019-04-23T15:38:41Z', 'content': 'Pink revealed on Monday that she\'s decided to stop posting pictures of her children online. \r\n The singer made the announcement during an appearance on "The Ellen Show," after Ellen DeGeneres asked her to address a controversial photo she recently posted, whi… [+1654 chars]'}, {'source': {'id': None, 'name': 'Yahoo.com'}, 'author': None, 'title': 'Trump sues Deutsche Bank and Capital One to block House subpoenas', 'description': 'The federal lawsuit, filed in the U.S. District Court\'s Southern District of New York, contended that demands for records by Democrat-controlled House committees have no legitimate or lawful purpose. "The subpoenas were issued to harass President Donald J. Tr…', 'url': 'https://news.yahoo.com/trump-sues-deutsche-bank-capital-one-block-house-044450906--sector.html', 'urlToImage': 'https://s.yimg.com/uu/api/res/1.2/c5HptTbk9hLnGpAzE7V7PA--~B/aD0zMDA7dz00NTA7c209MTthcHBpZD15dGFjaHlvbg--/http://media.zenfs.com/en_us/News/Reuters/2019-04-30T044450Z_1_LYNXNPEF3T057_RTROPTP_2_DEUTSCHE-BANK-RESULTS.JPG', 'publishedAt': '2019-04-30T06:03:39Z', 'content': 'By Rich McKay\r\n(Reuters) - U.S. President Donald Trump, three of his children and seven of his companies filed a federal lawsuit Monday against Deutsche Bank and Capital One Financial Corp to block the banks from complying with federal subpoenas investigating… [+2247 chars]'}, {'source': {'id': None, 'name': 'Thisisinsider.com'}, 'author': 'Beatrice Christofaro', 'title': "A 'hero' 3-year-old girl kept her baby brother alive for as long as 3 days after their parents' apparent murder-suicide", 'description': "Warning: This article contains details of suicide. A three-year-old girl kept her infant brother safe for days after what police believe was their parents' murder-suicide. Investigators believe their father David Kooros Parsa shot their mother Mihoko Koike Pa…", 'url': 'https://www.thisisinsider.com/girl-3-kept-baby-brother-safe-after-parent-murder-suicide-in-la-2019-4', 'urlToImage': 'https://amp.businessinsider.com/images/5cc300ffc013350889191f20-1334-667.jpg', 'publishedAt': '2019-04-26T12:59:27Z', 'content': "A three-year-ol ...
